# %%
usuarios_data_science = [15, 23, 43, 56]
usuarios_machine_learning = [13, 23, 56, 42]

# %%
assistiram = usuarios_data_science.copy()
assistiram.extend(usuarios_machine_learning)
assistiram
# Out:
# [15, 23, 43, 56, 13, 23, 56, 42]

# %%
len(assistiram)
# Out:
# 8

# %%
set(assistiram) # conjunto
# Out:
# {13, 15, 23, 42, 43, 56}

# %%
set([1,2,3,1])
# Out:
# {1, 2, 3}

# %%
{4,1,2,3,1}
# Out:
# {1, 2, 3, 4}

# %%
type({1,2,3})
# Out:
# set

# %%
usuarios_data_science = {15, 23, 43, 56}
usuarios_machine_learning = {13, 23, 56, 42}

# %%
usuarios_machine_learning
# Out:
# {13, 23, 42, 56}

# %%
usuarios_machine_learning[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# g:\Meu Drive\Cursos\Alura\Back-End\Python\Python3-parte6-Collections-parte2\Continuando com Collections.ipynb Cell 10' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Cursos/Alura/Back-End/Python/Python3-parte6-Collections-parte2/Continuando%20com%20Collections.ipynb#ch0000009?line=0'>1</a> usuarios_machine_learning[3]
#
# TypeError: 'set' object is not subscriptable

# %%
for usuario in set(assistiram):
  print(usuario)
# Out:
# 42
# 43
# 13
# 15
# 23
# 56

# %%
usuarios_data_science = {15, 23, 43, 56}
usuarios_machine_learning = {13, 23, 56, 42}

# %%
usuarios_data_science | usuarios_machine_learning
# Out:
# {13, 15, 23, 42, 43, 56}

# %%
usuarios_data_science & usuarios_machine_learning
# Out:
# {23, 56}

# %%
usuarios_data_science - usuarios_machine_learning
# Out:
# {15, 43}

# %%
fez_ds_mas_nao_fez_ml = usuarios_data_science - usuarios_machine_learning
15 in fez_ds_mas_nao_fez_ml
# Out:
# True

# %%
23 in fez_ds_mas_nao_fez_ml
# Out:
# False

# %%
usuarios_data_science ^ usuarios_machine_learning
# Out:
# {13, 15, 42, 43}
