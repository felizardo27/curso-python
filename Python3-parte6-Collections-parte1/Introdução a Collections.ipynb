# %%
idade1 = 39
idade2 = 30
idade3 = 27
idade4 = 18

print(idade1)
print(idade2)
print(idade3)
print(idade4)
# Out:
# 39
# 30
# 27
# 18

# %%
idades = [39, 30, 27, 18]

# %%
type(idades)
# Out:
# list

# %%
len(idades)
# Out:
# 4

# %%
idades[0]
# Out:
# 39

# %%
idades
# Out:
# [39, 30, 27, 18]

# %%
print(idades[1])
print(idades[2])
print(idades[3])
# Out:
# 30
# 27
# 18

# %%
idades.append(15)

# %%
idades
# Out:
# [39, 30, 27, 18, 15]

# %%
idades[4]
# Out:
# 15

# %%
idades[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-9afc071113c0> in <module>()
# ----> 1 idades[5]
#
# IndexError: list index out of range

# %%
for idade in idades:
  print(idade)
# Out:
# 39
# 30
# 27
# 18
# 15

# %%
idades.remove(30)

# %%
idades
# Out:
# [39, 27, 18, 15]

# %%
idades.remove(30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-4f77f6ee3785> in <module>()
# ----> 1 idades.remove(30)
#
# ValueError: list.remove(x): x not in list

# %%
idades.append(15)

# %%
idades
# Out:
# [39, 27, 18, 15, 15]

# %%
idades.remove(15)

# %%
idades
# Out:
# [39, 27, 18, 15]

# %%
idades.append(27)
idades.remove(27)
idades
# Out:
# [39, 18, 15, 27]

# %%
28 in idades
# Out:
# False

# %%
15 in idades
# Out:
# True

# %%
if 15 in idades:
  idades.remove(15)

# %%
idades
# Out:
# [39, 18, 27]

# %%
if 28 in idades:
  idades.remove(28)

# %%
idades
# Out:
# [39, 18, 27]

# %%
idades.append(19)

# %%
idades
# Out:
# [39, 18, 27, 19]

# %%
idades.insert(0, 20)
idades
# Out:
# [20, 39, 18, 27, 19]

# %%
idades = [20, 39, 18]
idades
# Out:
# [20, 39, 18]

# %%
idades.append([27, 19])

# %%
idades
# Out:
# [20, 39, 18, [27, 19]]

# %%
for elemento in idades:
  print(f"Recebi o elemento: {elemento}")
# Out:
# Recebi o elemento: 20
# Recebi o elemento: 39
# Recebi o elemento: 18
# Recebi o elemento: [27, 19]

# %%
idades = [20, 39, 18]
idades.extend([27, 19])
idades
# Out:
# [20, 39, 18, 27, 19]

# %%
for idade in idades:
  print(idade+1)
# Out:
# 21
# 40
# 19
# 28
# 20

# %%
idades_no_ano_que_vem = []
for idade in idades:
  idades_no_ano_que_vem.append(idade+1)
idades_no_ano_que_vem
# Out:
# [21, 40, 19, 28, 20]

# %%
idades_no_ano_que_vem = [(idade + 1) for idade in idades]
idades_no_ano_que_vem
# Out:
# [21, 40, 19, 28, 20]

# %%
[idade for idade in idades if idade > 21]
# Out:
# [39, 27]

# %%
idades
# Out:
# [20, 39, 18, 27, 19]

# %%
def proximo_ano(idade):
  return idade+1


[proximo_ano(idade) for idade in idades if idade > 21]
# Out:
# [40, 28]

# %%
def faz_processamento_de_visualizacao(lista):
  print(len(lista))
  lista.append(13)

# %%
idades = [16, 21, 29, 59, 43]
faz_processamento_de_visualizacao(idades)
idades
# Out:
# 5
# [16, 21, 29, 59, 43, 13]

# %%
def faz_processamento_de_visualizacao(lista = []):
  print(len(lista))
  lista.append(13)

# %%
faz_processamento_de_visualizacao()
# Out:
# 0

# %%
faz_processamento_de_visualizacao()
# Out:
# 1

# %%
faz_processamento_de_visualizacao()
# Out:
# 2

# %%
faz_processamento_de_visualizacao()
# Out:
# 3

# %%
def faz_processamento_de_visualizacao(lista = list()):
  print(len(lista))
  print(lista)
  lista.append(13)

# %%
faz_processamento_de_visualizacao()
faz_processamento_de_visualizacao()
# Out:
# 0
# []
# 1
# [13]

# %%
def faz_processamento_de_visualizacao(lista = None):
  if lista == None:
    lista = list()
  print(len(lista))
  print(lista)
  lista.append(13)

# %%
faz_processamento_de_visualizacao()
faz_processamento_de_visualizacao()
faz_processamento_de_visualizacao()
faz_processamento_de_visualizacao()
# Out:
# 0
# []
# 0
# []
# 0
# []
# 0
# []

# %% [markdown]
# #Objetos próprios

# %%
class ContaCorrente:
  
  def __init__(self, codigo):
    self.codigo = codigo
    self.saldo = 0

  def deposita(self, valor):
    self.saldo += valor

  def __str__(self):
    return f"[>>Codigo {self.codigo} Saldo {self.saldo}<<]"

# %%
conta_do_cleiton = ContaCorrente(15)
print(conta_do_cleiton)
# Out:
# [>>Codigo 15 Saldo 0<<]

# %%
conta_do_cleiton.deposita(500)
print(conta_do_cleiton)
# Out:
# [>>Codigo 15 Saldo 500<<]

# %%
conta_da_dani = ContaCorrente(47685)
conta_da_dani.deposita(1000)
print(conta_da_dani)
# Out:
# [>>Codigo 47685 Saldo 1000<<]

# %%
contas = [conta_do_cleiton, conta_da_dani]
for conta in contas:
  print(conta)
# Out:
# [>>Codigo 15 Saldo 500<<]
# [>>Codigo 47685 Saldo 1000<<]

# %%
contas = [conta_do_cleiton, conta_da_dani, conta_do_cleiton]

# %%
print(contas[0])
# Out:
# [>>Codigo 15 Saldo 500<<]

# %%
conta_do_cleiton.deposita(100)

# %%
print(contas[0])
# Out:
# [>>Codigo 15 Saldo 600<<]

# %%
print(conta_do_cleiton)
# Out:
# [>>Codigo 15 Saldo 600<<]

# %%
for conta in contas:
  print(conta)
# Out:
# [>>Codigo 15 Saldo 600<<]
# [>>Codigo 47685 Saldo 1000<<]
# [>>Codigo 15 Saldo 600<<]

# %%
contas[2].deposita(300)

# %%
print(conta_do_cleiton)
# Out:
# [>>Codigo 15 Saldo 900<<]

# %%
def deposita_para_todas(contas):
  for conta in contas:
    conta.deposita(100)

contas = [conta_do_cleiton, conta_da_dani]
print(contas[0], contas[1])
deposita_para_todas(contas)
print(contas[0], contas[1])
# Out:
# [>>Codigo 15 Saldo 900<<] [>>Codigo 47685 Saldo 1000<<]
# [>>Codigo 15 Saldo 1000<<] [>>Codigo 47685 Saldo 1100<<]

# %%
contas.insert(0, 76)
print(contas[0], contas[1], contas[2])
# Out:
# 76 [>>Codigo 15 Saldo 1000<<] [>>Codigo 47685 Saldo 1100<<]

# %%
deposita_para_todas(contas)
print(contas[0], contas[1], contas[2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-92ac4487eece> in <module>()
# ----> 1 deposita_para_todas(contas)
#       2 print(contas[0], contas[1], contas[2])
#
# <ipython-input-34-a5e2fa500a03> in deposita_para_todas(contas)
#       1 def deposita_para_todas(contas):
#       2   for conta in contas:
# ----> 3     conta.deposita(100)
#       4
#       5 contas = [conta_do_cleiton, conta_da_dani]
#
# AttributeError: 'int' object has no attribute 'deposita'

# %%
joao = ('João', 22, 1999) # tupla
cleiton = ('Cleiton', 25, 1997)
# paulo = (39, 'Paulo', 1979) # Ruim

# %%
joao.append(59649)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-a49a04ac7069> in <module>()
# ----> 1 joao.append(59649)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
conta_do_cleiton = (15, 1000)
# conta_do_cleiton() # variação oo
conta_do_cleiton[1]
# Out:
# 1000

# %%
conta_do_cleiton[1]+=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-808ef55eca2d> in <module>()
# ----> 1 conta_do_cleiton[1]+=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
def deposita(conta): # variacao funcional (separando o comportamento dos dados)
  novo_saldo = conta[1] + 100
  codigo = conta[0]
  return (codigo, novo_saldo)

# %%
deposita(conta_do_cleiton)
# Out:
# (15, 1100)

# %%
conta_do_cleiton
# Out:
# (15, 1000)

# %%
conta_do_cleiton = deposita(conta_do_cleiton)
conta_do_cleiton
# Out:
# (15, 1200)

# %%
usuarios = [joao, cleiton]
usuarios
# Out:
# [('João', 22, 1999), ('Cleiton', 25, 1997)]

# %%
usuarios.append(('Paulo', 39, 1979))
usuarios
# Out:
# [('João', 22, 1999), ('Cleiton', 25, 1997), ('Paulo', 39, 1979)]

# %%
usuarios[0][0] = 'João Pedro'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-0987bb7e3781> in <module>()
# ----> 1 usuarios[0][0] = 'João Pedro'
#
# TypeError: 'tuple' object does not support item assignment

# %%
conta_do_cleiton = ContaCorrente(15)
conta_do_cleiton.deposita(100)
conta_da_dani = ContaCorrente(23265)
conta_da_dani.deposita(1000)

contas = (conta_do_cleiton, conta_da_dani)

# %%
for conta in contas:
  print(conta)
# Out:
# [>>Codigo 15 Saldo 100<<]
# [>>Codigo 23265 Saldo 1000<<]

# %%
contas.append(23414)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-a3c0e3df20e3> in <module>()
# ----> 1 contas.append(23414)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
contas[0].deposita(300)

# %%
for conta in contas:
  print(conta)
# Out:
# [>>Codigo 15 Saldo 400<<]
# [>>Codigo 23265 Saldo 1000<<]

# %% [markdown]
# #Herança e polimorfismo

# %%
#definindo classe abstrata

from abc import ABCMeta, abstractmethod

class Conta(metaclass=ABCMeta):
  
  def __init__(self, codigo):
    self._codigo = codigo
    self._saldo = 0

  def deposita(self, valor):
    self._saldo += valor

  @abstractmethod
  def passa_o_mes(self):
    pass

  def __str__(self):
    return f"[>>Codigo {self._codigo} Saldo {self._saldo}<<]"

# %%
print(Conta(88))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-bcabbe50454b> in <module>()
# ----> 1 print(Conta(88))
#
# TypeError: Can't instantiate abstract class Conta with abstract methods passa_o_mes

# %%
class ContaCorrente(Conta):
  
  def passa_o_mes(self):
    self._saldo -= 2
  
class ContaPoupanca(Conta):

  def passa_o_mes(self):
    self._saldo *= 1.01
    self._saldo -= 3

class ContaInvestimento(Conta):
  pass

# %%
ContaInvestimento(785)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-1615f3e99a76> in <module>()
# ----> 1 ContaInvestimento(785)
#
# TypeError: Can't instantiate abstract class ContaInvestimento with abstract methods passa_o_mes

# %%
conta16 = ContaCorrente(16)
conta16.deposita(1000)
conta16.passa_o_mes()
print(conta16)
# Out:
# [>>Codigo 16 Saldo 998<<]

# %%
conta17 = ContaPoupanca(17)
conta17.deposita(1000)
conta17.passa_o_mes()
print(conta17)
# Out:
# [>>Codigo 17 Saldo 1007.0<<]

# %%
conta16 = ContaCorrente(16)
conta16.deposita(1000)
conta17 = ContaPoupanca(17)
conta17.deposita(1000)
contas = [conta16, conta17]

for conta in contas:
  conta.passa_o_mes() # duck typing
  print(conta)
# Out:
# [>>Codigo 16 Saldo 998<<]
# [>>Codigo 17 Saldo 1007.0<<]

# %% [markdown]
# # evitaremos usar array puro,se precisamos de trabalho numérico, é costume usar o numpy

# %%
import array as arr

arr.array('d', [1,3.5])
# Out:
# array('d', [1.0, 3.5])

# %%
arr.array('d', [1,3.5, 'Teste'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-b33ad23746a3> in <module>()
# ----> 1 arr.array('d', [1,3.5, 'Teste'])
#
# TypeError: must be real number, not str

# %%
# !pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np

numeros = np.array([1, 3.5])
numeros
# Out:
# array([1. , 3.5])

# %%
numeros + 3
# Out:
# array([4. , 6.5])

# %%
class ContaSalario:

  def __init__(self, codigo):
    self._codigo = codigo
    self._saldo = 0

  def deposita(self, valor):
    self._saldo += valor

  def __str__(self):
    return f"[>>Coodigo {self._codigo} Saldo {self._saldo}<<]"

# %%
conta1 = ContaSalario(37)
print(conta1)
# Out:
# [>>Coodigo 37 Saldo 0<<]

# %%
conta2 = ContaSalario(37)
print(conta2)
# Out:
# [>>Coodigo 37 Saldo 0<<]

# %%
conta1 == conta2
# Out:
# False

# %%
contas = [conta1]
conta1 in contas
# Out:
# True

# %%
conta2 in contas
# Out:
# False

# %%
class ContaSalario:

  def __init__(self, codigo):
    self._codigo = codigo
    self._saldo = 0

  def __eq__(self, outro):
    return self._codigo == outro._codigo

  def deposita(self, valor):
    self._saldo += valor

  def __str__(self):
    return f"[>>Coodigo {self._codigo} Saldo {self._saldo}<<]"

# %%
conta1 = ContaSalario(37)
conta2 = ContaSalario(37)

# %%
conta1 == conta2
# Out:
# True

# %%
conta1 != conta2
# Out:
# False

# %%
conta1 in [conta2]
# Out:
# True

# %%
conta2 in [conta1]
# Out:
# True

# %%
class ContaSalario:

  def __init__(self, codigo):
    self._codigo = codigo
    self._saldo = 0

  def __eq__(self, outro):
    return self._codigo == outro._codigo and self._saldo == outro._saldo

  def deposita(self, valor):
    self._saldo += valor

  def __str__(self):
    return f"[>>Coodigo {self._codigo} Saldo {self._saldo}<<]"

# %%
conta1 = ContaSalario(37)
conta2 = ContaSalario(37)
conta1 == conta2
# Out:
# True

# %%
conta1.deposita(10)

# %%
conta1 == conta2
# Out:
# False

# %%
class ContaSalario:

  def __init__(self, codigo):
    self._codigo = codigo
    self._saldo = 0

  def __eq__(self, outro):
    if type(outro) != ContaSalario:
      return False
    return self._codigo == outro._codigo and self._saldo == outro._saldo

  def deposita(self, valor):
    self._saldo += valor

  def __str__(self):
    return f"[>>Coodigo {self._codigo} Saldo {self._saldo}<<]"

# %%
conta1 = ContaSalario(37)
conta2 = ContaCorrente(37)

# %%
conta1 == conta2
# Out:
# False

# %%
isinstance(ContaCorrente(37), ContaCorrente)
# Out:
# True

# %%
isinstance(ContaCorrente(37), Conta)
# Out:
# True
